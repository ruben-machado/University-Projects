# %% [markdown]
# # <font color=2b7cb6> **Data Mining II - Budgeting For The Future** </font>
# ## <font color=4f9dd6> **Notebook 3:** </font>
#
# <u>**Group 06:**</u>
# - Eduardo Amaral, 20230355
# - Joana Oliveira, 20230384
# - João Freitas, 20231472
# - Rúben Machado, 20230367
# - Teresa Santos, 20230380

# %% [markdown]
# ## <font color=72beea> **Imports** </font>

# %%
# To show all ouput that are in the same input cell (allow to run more than one function/method in the same cell)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
path = '/content/drive/MyDrive/Homework_Group06/'
# Out:
# Mounted at /content/drive

# %%
# Import clean_train dataset
predict_test = pd.read_csv(path + 'DM2_Project Datasets/DT_Group06_Version42.csv', index_col='citizen_id')
predict_test
# Out:
#                 lifestyle_type
# citizen_id
# 90166        Travel Enthusiast
# 90167       Fitness Enthusiast
# 90168       Fitness Enthusiast
# 90169         Adventure Seeker
# 90170        Travel Enthusiast
# ...                        ...
# 128804        Adventure Seeker
# 128805       Travel Enthusiast
# 128806        Adventure Seeker
# 128807       Travel Enthusiast
# 128808      Fitness Enthusiast
#
# [38643 rows x 1 columns]

# %%
# Get the value counts
value_counts = predict_test['lifestyle_type'].value_counts().sort_index()
# Calculate the percentages
percentages = value_counts / value_counts.sum() * 100
# Combine the counts and percentages into a DataFrame
counts_and_percentages = pd.DataFrame({'Count': value_counts, 'Percentage': percentages})
print(counts_and_percentages)
# Out:
#                     Count  Percentage
# lifestyle_type
# Adventure Seeker     7980   20.650571
# Fitness Enthusiast   7548   19.532645
# Health-Conscious     7763   20.089020
# Investor             7875   20.378853
# Travel Enthusiast    7477   19.348912

# %%
# Plotting
fig, ax = plt.subplots(figsize=(15, 4))

# Plot for investment_profile
sns.countplot(x='lifestyle_type', data=predict_test, palette='Set2', ax=ax)
ax.set_title('Lifestyle Type')
ax.set_xlabel('Lifestyle Type')
ax.set_ylabel('Count')
# Out:
# <Axes: xlabel='lifestyle_type', ylabel='count'>
# Text(0.5, 1.0, 'Lifestyle Type')
# Text(0.5, 0, 'Lifestyle Type')
# Text(0, 0.5, 'Count')
